# %%
# import các thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#kết nối colab với dữ liệu của Google Driver
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/Datasets
# Out:
# /content/drive/MyDrive/ColabNotebooks/Datasets

# %%
df = pd.read_csv("new_train1.csv")

# %%
df.head()
# Out:
#    age           job   marital          education  default housing loan  \
# 0   49   blue-collar   married           basic.9y  unknown      no   no
# 1   37  entrepreneur   married  university.degree       no      no   no
# 2   78       retired   married           basic.4y       no      no   no
# 3   36        admin.   married  university.degree       no     yes   no
# 4   59       retired  divorced  university.degree       no      no   no
#
#      contact month day_of_week  duration  previous     poutcome    y
# 0   cellular   nov         wed       227         0  nonexistent   no
# 1  telephone   nov         wed       202         1      failure   no
# 2   cellular   jul         mon      1148         0  nonexistent  yes
# 3  telephone   may         mon       120         0  nonexistent   no
# 4   cellular   jun         tue       368         0  nonexistent   no

# %%
for i in range(0, len(df.age)):
    if 10 < df.age[i] < 20:
        df.age[i] = 0
    elif 20 < df.age[i] < 35:
        df.age[i] = 1
    elif 35 < df.age[i] < 45:
        df.age[i] = 2
    elif 40 < df.age[i] < 55:
        df.age[i] = 3
    elif 55 < df.age[i] < 65:
        df.age[i] = 4
    elif 65 < df.age[i] < 75:
        df.age[i] = 5
    elif 75 < df.age[i] < 85:
        df.age[i] = 6
    elif 75 < df.age[i] < 95:
        df.age[i] = 7
    else:
        df.age[i] = 8
    df.age[i]+=1
    print("age",i," is changed to",df.age[i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# age 0  is changed to 4
# age 1  is changed to 3
# age 2  is changed to 7
# age 3  is changed to 3
# age 4  is changed to 5
# age 5  is changed to 2
# age 6  is changed to 2
# age 7  is changed to 2
# age 8  is changed to 4
# age 9  is changed to 2
# age 10  is changed to 3
# age 11  is changed to 2
# age 12  is changed to 2
# age 13  is changed to 3
# age 14  is changed to 5
# age 15  is changed to 3
# age 16  is changed to 2
# age 17  is changed to 4
# age 18  is changed to 4
# age 19  is changed to 2
# age 20  is changed to 4
# age 21  is changed to 3
# age 22  is changed to 3
# age 23  is changed to 2
# age 24  is changed to 9
# age 25  is changed to 2
# age 26  is changed to 4
# age 27  is changed to 3
# age 28  is changed to 3
# age 29  is changed to 2
# age 30  is changed to 2
# age 31  is changed to 5
# age 32  is changed to 4
# age 33  is changed to 3
# age 34  is changed to 9
# age 35  is changed to 2
# age 36  is changed to 2
# age 37  is changed to 2
# age 38  is changed to 2
# age 39  is changed to 2
# age 40  is changed to 3
# age 41  is changed to 2
# age 42  is changed to 3
# age 43  is changed to 9
# age 44  is changed to 2
# age 45  is changed to 4
# age 46  is changed to 3
# age 47  is changed to 4
# age 48  is changed to 4
# age 49  is changed to 3
# age 50  is changed to 4
# age 51  is changed to 5
# age 52  is changed to 4
# age 53  is changed to 9
# age 54  is changed to 4
# age 55  is changed to 2
# age 56  is changed to 3
# age 57  is changed to 5
# age 58  is changed to 9
# age 59  is changed to 4
# age 60  is changed to 4
# age 61  is changed to 3
# age 62  is changed to 3
# age 63  is changed to 3
# age 64  is changed to 4
# age 65  is changed to 2
# age 66  is changed to 2
# age 67  is changed to 3
# age 68  is changed to 6
# age 69  is changed to 2
# age 70  is changed to 2
# age 71  is changed to 5
# age 72  is changed to 2
# age 73  is changed to 3
# age 74  is changed to 3
# age 75  is changed to 3
# age 76  is changed to 4
# age 77  is changed to 3
# age 78  is changed to 4
# age 79  is changed to 4
# age 80  is changed to 2
# age 81  is changed to 4
# age 82  is changed to 2
# age 83  is changed to 9
# age 84  is changed to 2
# age 85  is changed to 3
# age 86  is changed to 4
# age 87  is changed to 2
# age 88  is changed to 7
# age 89  is changed to 2
# age 90  is changed to 4
# age 91  is changed to 3
# age 92  is changed to 4
# age 93  is changed to 4
# age 94  is changed to 2
# age 95  is changed to 4
# age 96  is changed to 3
# age 97  is changed to 4
# age 98  is changed to 2
# age 99  is changed to 2
# age 100  is changed to 2
# age 101  is changed to 9
# age 102  is changed to 4
# age 103  is changed to 4
# age 104  is changed to 2
# age 105  is changed to 3
# age 106  is changed to 2
# age 107  is changed to 2
# age 108  is changed to 3
# age 109  is changed to 7
# age 110  is changed to 5
# age 111  is changed to 3
# age 112  is changed to 3
# age 113  is changed to 3
# age 114  is changed to 2
# age 115  is changed to 3
# age 116  is changed to 9
# age 117  is changed to 3
# age 118  is changed to 3
# age 119  is changed to 2
# age 120  is changed to 5
# age 121  is changed to 3
# age 122  is changed to 4
# age 123  is changed to 3
# age 124  is changed to 4
# age 125  is changed to 2
# age 126  is changed to 2
# age 127  is changed to 3
# age 128  is changed to 2
# age 129  is changed to 3
# age 130  is changed to 4
# age 131  is changed to 3
# age 132  is changed to 2
# age 133  is changed to 2
# age 134  is changed to 2
# age 135  is changed to 2
# age 136  is changed to 4
# age 137  is changed to 4
# age 138  is changed to 2
# age 139  is changed to 2
# age 140  is changed to 2
# age 141  is changed to 3
# age 142  is changed to 3
# age 143  is changed to 3
# age 144  is changed to 3
# age 145  is changed to 3
# age 146  is changed to 2
# age 147  is changed to 4
# age 148  is changed to 3
# age 149  is changed to 2
# age 150  is changed to 3
# age 151  is changed to 2
# age 152  is changed to 3
# age 153  is changed to 3
# age 154  is changed to 3
# age 155  is changed to 9
# age 156  is changed to 2
# age 157  is changed to 4
# age 158  is changed to 9
# age 159  is changed to 2
# age 160  is changed to 2
# age 161  is changed to 3
# age 162  is changed to 3
# age 163  is changed to 4
# age 164  is changed to 3
# age 165  is changed to 3
# age 166  is changed to 3
# age 167  is changed to 3
# age 168  is changed to 5
# age 169  is changed to 4
# age 170  is changed to 4
# age 171  is changed to 5
# age 172  is changed to 3
# age 173  is changed to 4
# age 174  is changed to 4
# age 175  is changed to 9
# age 176  is changed to 4
# age 177  is changed to 4
# age 178  is changed to 2
# age 179  is changed to 4
# age 180  is changed to 3
# age 181  is changed to 2
# age 182  is changed to 2
# age 183  is changed to 3
# age 184  is changed to 2
# age 185  is changed to 3
# age 186  is changed to 2
# age 187  is changed to 2
# age 188  is changed to 5
# age 189  is changed to 2
# age 190  is changed to 2
# age 191  is changed to 3
# age 192  is changed to 9
# age 193  is changed to 3
# age 194  is changed to 3
# age 195  is changed to 4
# age 196  is changed to 4
# age 197  is changed to 2
# age 198  is changed to 9
# age 199  is changed to 2
# age 200  is changed to 2
# age 201  is changed to 3
# age 202  is changed to 2
# age 203  is changed to 4
# age 204  is changed to 3
# age 205  is changed to 3
# age 206  is changed to 9
# age 207  is changed to 2
# age 208  is changed to 4
# age 209  is changed to 3
# age 210  is changed to 3
# age 211  is changed to 3
# age 212  is changed to 4
# age 213  is changed to 4
# age 214  is changed to 3
# age 215  is changed to 4
# age 216  is changed to 4
# age 217  is changed to 9
# age 218  is changed to 3
# age 219  is changed to 3
# age 220  is changed to 3
# age 221  is changed to 4
# age 222  is changed to 3
# age 223  is changed to 2
# age 224  is changed to 2
# age 225  is changed to 4
# age 226  is changed to 3
# age 227  is changed to 2
# age 228  is changed to 3
# age 229  is changed to 5
# age 230  is changed to 2
# age 231  is changed to 2
# age 232  is changed to 3
# age 233  is changed to 3
# age 234  is changed to 2
# age 235  is changed to 2
# age 236  is changed to 4
# age 237  is changed to 4
# age 238  is changed to 2
# age 239  is changed to 5
# age 240  is changed to 2
# age 241  is changed to 3
# age 242  is changed to 2
# age 243  is changed to 2
# age 244  is changed to 4
# age 245  is changed to 3
# age 246  is changed to 2
# age 247  is changed to 2
# age 248  is changed to 2
# age 249  is changed to 4
# age 250  is changed to 3
# age 251  is changed to 2
# age 252  is changed to 2
# age 253  is changed to 4
# age 254  is changed to 5
# age 255  is changed to 2
# age 256  is changed to 2
# age 257  is changed to 2
# age 258  is changed to 3
# age 259  is changed to 2
# age 260  is changed to 4
# age 261  is changed to 4
# age 262  is changed to 3
# age 263  is changed to 3
# age 264  is changed to 9
# age 265  is changed to 5
# age 266  is changed to 9
# age 267  is changed to 9
# age 268  is changed to 4
# age 269  is changed to 2
# age 270  is changed to 2
# age 271  is changed to 5
# age 272  is changed to 4
# age 273  is changed to 2
# age 274  is changed to 2
# age 275  is changed to 2
# age 276  is changed to 2
# age 277  is changed to 2
# age 278  is changed to 3
# age 279  is changed to 2
# age 280  is changed to 7
# age 281  is changed to 9
# age 282  is changed to 2
# age 283  is changed to 2
# age 284  is changed to 2
# age 285  is changed to 3
# age 286  is changed to 3
# age 287  is changed to 3
# age 288  is changed to 5
# age 289  is changed to 2
# age 290  is changed to 5
# age 291  is changed to 2
# age 292  is changed to 3
# age 293  is changed to 9
# age 294  is changed to 2
# age 295  is changed to 2
# age 296  is changed to 3
# age 297  is changed to 4
# age 298  is changed to 2
# age 299  is changed to 4
# age 300  is changed to 4
# age 301  is changed to 5
# age 302  is changed to 4
# age 303  is changed to 4
# age 304  is changed to 2
# age 305  is changed to 3
# age 306  is changed to 3
# age 307  is changed to 4
# age 308  is changed to 2
# age 309  is changed to 2
# age 310  is changed to 3
# age 311  is changed to 3
# age 312  is changed to 2
# age 313  is changed to 4
# age 314  is changed to 3
# age 315  is changed to 3
# age 316  is changed to 4
# age 317  is changed to 2
# age 318  is changed to 2
# age 319  is changed to 4
# age 320  is changed to 4
# age 321  is changed to 2
# age 322  is changed to 2
# age 323  is changed to 3
# age 324  is changed to 4
# age 325  is changed to 4
# age 326  is changed to 2
# age 327  is changed to 2
# age 328  is changed to 2
# age 329  is changed to 3
# age 330  is changed to 9
# age 331  is changed to 3
# age 332  is changed to 3
# age 333  is changed to 2
# age 334  is changed to 2
# age 335  is changed to 3
# age 336  is changed to 3
# age 337  is changed to 4
# age 338  is changed to 9
# age 339  is changed to 4
# age 340  is changed to 2
# age 341  is changed to 3
# age 342  is changed to 4
# age 343  is changed to 3
# age 344  is changed to 2
# age 345  is changed to 2
# age 346  is changed to 3
# age 347  is changed to 4
# age 348  is changed to 4
# age 349  is changed to 3
# age 350  is changed to 3
# age 351  is changed to 2
# age 352  is changed to 2
# age 353  is changed to 4
# age 354  is changed to 3
# age 355  is changed to 3
# age 356  is changed to 5
# age 357  is changed to 2
# age 358  is changed to 5
# age 359  is changed to 3
# age 360  is changed to 5
# age 361  is changed to 2
# age 362  is changed to 3
# age 363  is changed to 2
# age 364  is changed to 4
# age 365  is changed to 2
# age 366  is changed to 3
# age 367  is changed to 3
# age 368  is changed to 2
# age 369  is changed to 3
# age 370  is changed to 4
# age 371  is changed to 4
# age 372  is changed to 2
# age 373  is changed to 3
# age 374  is changed to 2
# age 375  is changed to 5
# age 376  is changed to 2
# age 377  is changed to 4
# age 378  is changed to 3
# age 379  is changed to 2
# age 380  is changed to 4
# age 381  is changed to 2
# age 382  is changed to 3
# age 383  is changed to 2
# age 384  is changed to 2
# age 385  is changed to 4
# age 386  is changed to 3
# age 387  is changed to 9
# age 388  is changed to 3
# age 389  is changed to 2
# age 390  is changed to 4
# age 391  is changed to 4
# age 392  is changed to 3
# age 393  is changed to 9
# age 394  is changed to 2
# age 395  is changed to 2
# age 396  is changed to 2
# age 397  is changed to 3
# age 398  is changed to 2
# age 399  is changed to 3
# age 400  is changed to 2
# age 401  is changed to 3
# age 402  is changed to 2
# age 403  is changed to 2
# age 404  is changed to 2
# age 405  is changed to 2
# age 406  is changed to 2
# age 407  is changed to 2
# age 408  is changed to 2
# age 409  is changed to 2
# age 410  is changed to 3
# age 411  is changed to 2
# age 412  is changed to 3
# age 413  is changed to 2
# age 414  is changed to 4
# age 415  is changed to 3
# age 416  is changed to 2
# age 417  is changed to 2
# age 418  is changed to 4
# age 419  is changed to 2
# age 420  is changed to 5
# age 421  is changed to 3
# age 422  is changed to 2
# age 423  is changed to 3
# age 424  is changed to 3
# age 425  is changed to 2
# age 426  is changed to 3
# age 427  is changed to 3
# age 428  is changed to 2
# age 429  is changed to 4
# age 430  is changed to 2
# age 431  is changed to 5
# age 432  is changed to 4
# age 433  is changed to 2
# age 434  is changed to 4
# age 435  is changed to 3
# age 436  is changed to 2
# age 437  is changed to 9
# age 438  is changed to 4
# age 439  is changed to 5
# age 440  is changed to 3
# age 441  is changed to 2
# age 442  is changed to 4
# age 443  is changed to 2
# age 444  is changed to 2
# age 445  is changed to 9
# age 446  is changed to 3
# age 447  is changed to 2
# age 448  is changed to 3
# age 449  is changed to 2
# age 450  is changed to 2
# age 451  is changed to 5
# age 452  is changed to 4
# age 453  is changed to 2
# age 454  is changed to 4
# age 455  is changed to 3
# age 456  is changed to 4
# age 457  is changed to 2
# age 458  is changed to 4
# age 459  is changed to 2
# age 460  is changed to 3
# age 461  is changed to 2
# age 462  is changed to 2
# age 463  is changed to 2
# age 464  is changed to 3
# age 465  is changed to 5
# age 466  is changed to 3
# age 467  is changed to 5
# age 468  is changed to 4
# age 469  is changed to 2
# age 470  is changed to 3
# age 471  is changed to 2
# age 472  is changed to 9
# age 473  is changed to 5
# age 474  is changed to 3
# age 475  is changed to 4
# age 476  is changed to 4
# age 477  is changed to 2
# age 478  is changed to 2
# age 479  is changed to 2
# age 480  is changed to 3
# age 481  is changed to 3
# age 482  is changed to 2
# age 483  is changed to 2
# age 484  is changed to 3
# age 485  is changed to 5
# age 486  is changed to 4
# age 487  is changed to 2
# age 488  is changed to 3
# age 489  is changed to 2
# age 490  is changed to 3
# age 491  is changed to 2
# age 492  is changed to 3
# age 493  is changed to 4
# age 494  is changed to 2
# age 495  is changed to 4
# age 496  is changed to 2
# age 497  is changed to 9
# age 498  is changed to 5
# age 499  is changed to 5
# age 500  is changed to 4
# age 501  is changed to 2
# age 502  is changed to 2
# age 503  is changed to 3
# age 504  is changed to 3
# age 505  is changed to 3
# age 506  is changed to 2
# age 507  is changed to 2
# age 508  is changed to 3
# age 509  is changed to 3
# age 510  is changed to 9
# age 511  is changed to 2
# age 512  is changed to 3
# age 513  is changed to 3
# age 514  is changed to 5
# age 515  is changed to 5
# age 516  is changed to 2
# age 517  is changed to 4
# age 518  is changed to 4
# age 519  is changed to 4
# age 520  is changed to 3
# age 521  is changed to 2
# age 522  is changed to 9
# age 523  is changed to 5
# age 524  is changed to 3
# age 525  is changed to 4
# age 526  is changed to 4
# age 527  is changed to 2
# age 528  is changed to 3
# age 529  is changed to 3
# age 530  is changed to 9
# age 531  is changed to 4
# age 532  is changed to 3
# age 533  is changed to 4
# age 534  is changed to 9
# age 535  is changed to 4
# age 536  is changed to 3
# age 537  is changed to 5
# age 538  is changed to 4
# age 539  is changed to 4
# age 540  is changed to 3
# age 541  is changed to 4
# age 542  is changed to 2
# age 543  is changed to 2
# age 544  is changed to 9
# age 545  is changed to 4
# age 546  is changed to 3
# age 547  is changed to 2
# age 548  is changed to 3
# age 549  is changed to 2
# age 550  is changed to 6
# age 551  is changed to 3
# age 552  is changed to 5
# age 553  is changed to 2
# age 554  is changed to 2
# age 555  is changed to 4
# age 556  is changed to 3
# age 557  is changed to 2
# age 558  is changed to 2
# age 559  is changed to 2
# age 560  is changed to 2
# age 561  is changed to 4
# age 562  is changed to 3
# age 563  is changed to 4
# age 564  is changed to 2
# age 565  is changed to 4
# age 566  is changed to 2
# age 567  is changed to 4
# age 568  is changed to 3
# age 569  is changed to 2
# age 570  is changed to 2
# age 571  is changed to 2
# age 572  is changed to 2
# age 573  is changed to 2
# age 574  is changed to 3
# age 575  is changed to 2
# age 576  is changed to 4
# age 577  is changed to 3
# age 578  is changed to 3
# age 579  is changed to 5
# age 580  is changed to 3
# age 581  is changed to 2
# age 582  is changed to 2
# age 583  is changed to 2
# age 584  is changed to 4
# age 585  is changed to 4
# age 586  is changed to 5
# age 587  is changed to 2
# age 588  is changed to 2
# age 589  is changed to 2
# age 590  is changed to 4
# age 591  is changed to 5
# age 592  is changed to 2
# age 593  is changed to 2
# age 594  is changed to 4
# age 595  is changed to 3
# age 596  is changed to 5
# age 597  is changed to 4
# age 598  is changed to 3
# age 599  is changed to 2
# age 600  is changed to 2
# age 601  is changed to 2
# age 602  is changed to 3
# age 603  is changed to 2
# age 604  is changed to 5
# age 605  is changed to 4
# age 606  is changed to 9
# age 607  is changed to 4
# age 608  is changed to 3
# age 609  is changed to 2
# age 610  is changed to 4
# age 611  is changed to 2
# age 612  is changed to 3
# age 613  is changed to 4
# age 614  is changed to 2
# age 615  is changed to 2
# age 616  is changed to 5
# age 617  is changed to 9
# age 618  is changed to 2
# age 619  is changed to 3
# age 620  is changed to 4
# age 621  is changed to 3
# age 622  is changed to 2
# age 623  is changed to 4
# age 624  is changed to 2
# age 625  is changed to 2
# age 626  is changed to 2
# age 627  is changed to 3
# age 628  is changed to 3
# age 629  is changed to 4
# age 630  is changed to 3
# age 631  is changed to 2
# age 632  is changed to 2
# age 633  is changed to 3
# age 634  is changed to 2
# age 635  is changed to 3
# age 636  is changed to 2
# age 637  is changed to 2
# age 638  is changed to 3
# age 639  is changed to 4
# age 640  is changed to 2
# age 641  is changed to 3
# age 642  is changed to 3
# age 643  is changed to 2
# age 644  is changed to 2
# age 645  is changed to 2
# age 646  is changed to 2
# age 647  is changed to 4
# age 648  is changed to 3
# age 649  is changed to 3
# age 650  is changed to 2
# age 651  is changed to 3
# age 652  is changed to 2
# age 653  is changed to 3
# age 654  is changed to 7
# age 655  is changed to 5
# age 656  is changed to 4
# age 657  is changed to 4
# age 658  is changed to 3
# age 659  is changed to 9
# age 660  is changed to 2
# age 661  is changed to 3
# age 662  is changed to 2
# age 663  is changed to 4
# age 664  is changed to 3
# age 665  is changed to 2
# age 666  is changed to 9
# age 667  is changed to 2
# age 668  is changed to 3
# age 669  is changed to 2
# age 670  is changed to 3
# age 671  is changed to 3
# age 672  is changed to 3
# age 673  is changed to 2
# age 674  is changed to 9
# age 675  is changed to 3
# age 676  is changed to 2
# age 677  is changed to 9
# age 678  is changed to 5
# age 679  is changed to 2
# age 680  is changed to 2
# age 681  is changed to 9
# age 682  is changed to 2
# age 683  is changed to 2
# age 684  is changed to 2
# age 685  is changed to 3
# age 686  is changed to 3
# age 687  is changed to 9
# age 688  is changed to 4
# age 689  is changed to 2
# age 690  is changed to 5
# age 691  is changed to 2
# age 692  is changed to 3
# age 693  is changed to 3
# age 694  is changed to 2
# age 695  is changed to 5
# age 696  is changed to 4
# age 697  is changed to 2
# age 698  is changed to 3
# age 699  is changed to 2
# age 700  is changed to 3
# age 701  is changed to 2
# age 702  is changed to 3
# age 703  is changed to 3
# age 704  is changed to 4
# age 705  is changed to 2
# age 706  is changed to 7
# age 707  is changed to 2
# age 708  is changed to 2
# age 709  is changed to 3
# age 710  is changed to 3
# age 711  is changed to 3
# age 712  is changed to 2
# age 713  is changed to 3
# age 714  is changed to 3
# age 715  is changed to 2
# age 716  is changed to 2
# age 717  is changed to 3
# age 718  is changed to 3
# age 719  is changed to 2
# age 720  is changed to 3
# age 721  is changed to 2
# age 722  is changed to 4
# age 723  is changed to 2
# age 724  is changed to 9
# age 725  is changed to 2
# age 726  is changed to 4
# age 727  is changed to 9
# age 728  is changed to 2
# age 729  is changed to 2
# age 730  is changed to 5
# age 731  is changed to 7
# age 732  is changed to 9
# age 733  is changed to 4
# age 734  is changed to 2
# age 735  is changed to 2
# age 736  is changed to 2
# age 737  is changed to 3
# age 738  is changed to 4
# age 739  is changed to 2
# age 740  is changed to 2
# age 741  is changed to 5
# age 742  is changed to 2
# age 743  is changed to 4
# age 744  is changed to 3
# age 745  is changed to 2
# age 746  is changed to 2
# age 747  is changed to 2
# age 748  is changed to 2
# age 749  is changed to 4
# age 750  is changed to 3
# age 751  is changed to 4
# age 752  is changed to 4
# age 753  is changed to 3
# age 754  is changed to 9
# age 755  is changed to 4
# age 756  is changed to 2
# age 757  is changed to 2
# age 758  is changed to 3
# age 759  is changed to 3
# age 760  is changed to 9
# age 761  is changed to 1
# age 762  is changed to 3
# age 763  is changed to 9
# age 764  is changed to 2
# age 765  is changed to 2
# age 766  is changed to 3
# age 767  is changed to 3
# age 768  is changed to 4
# age 769  is changed to 4
# age 770  is changed to 9
# age 771  is changed to 3
# age 772  is changed to 2
# age 773  is changed to 2
# age 774  is changed to 7
# age 775  is changed to 2
# age 776  is changed to 4
# age 777  is changed to 3
# age 778  is changed to 2
# age 779  is changed to 3
# age 780  is changed to 3
# age 781  is changed to 5
# age 782  is changed to 2
# age 783  is changed to 3
# age 784  is changed to 2
# age 785  is changed to 2
# age 786  is changed to 4
# age 787  is changed to 2
# age 788  is changed to 4
# age 789  is changed to 2
# age 790  is changed to 2
# age 791  is changed to 4
# age 792  is changed to 4
# age 793  is changed to 2
# age 794  is changed to 2
# age 795  is changed to 5
# age 796  is changed to 2
# age 797  is changed to 3
# age 798  is changed to 9
# age 799  is changed to 3
# age 800  is changed to 2
# age 801  is changed to 2
# age 802  is changed to 2
# age 803  is changed to 9
# age 804  is changed to 3
# age 805  is changed to 4
# age 806  is changed to 4
# age 807  is changed to 3
# age 808  is changed to 2
# age 809  is changed to 2
# age 810  is changed to 9
# age 811  is changed to 4
# age 812  is changed to 4
# age 813  is changed to 3
# age 814  is changed to 4
# age 815  is changed to 5
# age 816  is changed to 4
# age 817  is changed to 3
# age 818  is changed to 4
# age 819  is changed to 3
# age 820  is changed to 3
# age 821  is changed to 3
# age 822  is changed to 3
# age 823  is changed to 2
# age 824  is changed to 4
# age 825  is changed to 5
# age 826  is changed to 2
# age 827  is changed to 3
# age 828  is changed to 2
# age 829  is changed to 2
# age 830  is changed to 2
# age 831  is changed to 3
# age 832  is changed to 2
# age 833  is changed to 9
# age 834  is changed to 4
# age 835  is changed to 3
# age 836  is changed to 2
# age 837  is changed to 2
# age 838  is changed to 2
# age 839  is changed to 4
# age 840  is changed to 3
# age 841  is changed to 2
# age 842  is changed to 4
# age 843  is changed to 5
# age 844  is changed to 4
# age 845  is changed to 3
# age 846  is changed to 9
# age 847  is changed to 2
# age 848  is changed to 4
# age 849  is changed to 3
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# age 850  is changed to 5
# age 851  is changed to 5
# age 852  is changed to 3
# age 853  is changed to 5
# age 854  is changed to 3
# age 855  is changed to 2
# age 856  is changed to 3
# age 857  is changed to 3
# age 858  is changed to 3
# age 859  is changed to 2
# age 860  is changed to 3
# age 861  is changed to 3
# age 862  is changed to 5
# age 863  is changed to 4
# age 864  is changed to 2
# age 865  is changed to 4
# age 866  is changed to 2
# age 867  is changed to 4
# age 868  is changed to 3
# age 869  is changed to 4
# age 870  is changed to 3
# age 871  is changed to 3
# age 872  is changed to 5
# age 873  is changed to 3
# age 874  is changed to 3
# age 875  is changed to 2
# age 876  is changed to 9
# age 877  is changed to 3
# age 878  is changed to 4
# age 879  is changed to 3
# age 880  is changed to 2
# age 881  is changed to 5
# age 882  is changed to 4
# age 883  is changed to 2
# age 884  is changed to 2
# age 885  is changed to 5
# age 886  is changed to 3
# age 887  is changed to 3
# age 888  is changed to 2
# age 889  is changed to 4
# age 890  is changed to 4
# age 891  is changed to 7
# age 892  is changed to 2
# age 893  is changed to 3
# age 894  is changed to 6
# age 895  is changed to 2
# age 896  is changed to 3
# age 897  is changed to 3
# age 898  is changed to 2
# age 899  is changed to 2
# age 900  is changed to 3
# age 901  is changed to 2
# age 902  is changed to 2
# age 903  is changed to 4
# age 904  is changed to 3
# age 905  is changed to 5
# age 906  is changed to 2
# age 907  is changed to 3
# age 908  is changed to 2
# age 909  is changed to 3
# age 910  is changed to 3
# age 911  is changed to 5
# age 912  is changed to 4
# age 913  is changed to 2
# age 914  is changed to 3
# age 915  is changed to 4
# age 916  is changed to 9
# age 917  is changed to 3
# age 918  is changed to 3
# age 919  is changed to 3
# age 920  is changed to 4
# age 921  is changed to 4
# age 922  is changed to 9
# age 923  is changed to 3
# age 924  is changed to 3
# age 925  is changed to 3
# age 926  is changed to 5
# age 927  is changed to 2
# age 928  is changed to 9
# age 929  is changed to 2
# age 930  is changed to 2
# age 931  is changed to 9
# age 932  is changed to 4
# age 933  is changed to 5
# age 934  is changed to 3
# age 935  is changed to 9
# age 936  is changed to 4
# age 937  is changed to 2
# age 938  is changed to 3
# age 939  is changed to 4
# age 940  is changed to 3
# age 941  is changed to 2
# age 942  is changed to 9
# age 943  is changed to 3
# age 944  is changed to 5
# age 945  is changed to 2
# age 946  is changed to 5
# age 947  is changed to 3
# age 948  is changed to 2
# age 949  is changed to 9
# age 950  is changed to 3
# age 951  is changed to 2
# age 952  is changed to 3
# age 953  is changed to 9
# age 954  is changed to 3
# age 955  is changed to 5
# age 956  is changed to 4
# age 957  is changed to 4
# age 958  is changed to 2
# age 959  is changed to 2
# age 960  is changed to 2
# age 961  is changed to 3
# age 962  is changed to 4
# age 963  is changed to 2
# age 964  is changed to 3
# age 965  is changed to 2
# age 966  is changed to 2
# age 967  is changed to 2
# age 968  is changed to 3
# age 969  is changed to 2
# age 970  is changed to 3
# age 971  is changed to 4
# age 972  is changed to 3
# age 973  is changed to 4
# age 974  is changed to 3
# age 975  is changed to 2
# age 976  is changed to 2
# age 977  is changed to 4
# age 978  is changed to 2
# age 979  is changed to 3
# age 980  is changed to 4
# age 981  is changed to 3
# age 982  is changed to 4
# age 983  is changed to 2
# age 984  is changed to 2
# age 985  is changed to 4
# age 986  is changed to 4
# age 987  is changed to 4
# age 988  is changed to 3
# age 989  is changed to 2
# age 990  is changed to 2
# age 991  is changed to 5
# age 992  is changed to 2
# age 993  is changed to 4
# age 994  is changed to 2
# age 995  is changed to 2
# age 996  is changed to 2
# age 997  is changed to 2
# age 998  is changed to 4
# age 999  is changed to 3
# age 1000  is changed to 2
# age 1001  is changed to 4
# age 1002  is changed to 2
# age 1003  is changed to 4
# age 1004  is changed to 2
# age 1005  is changed to 3
# age 1006  is changed to 4
# age 1007  is changed to 2
# age 1008  is changed to 3
# age 1009  is changed to 3
# age 1010  is changed to 2
# age 1011  is changed to 2
# age 1012  is changed to 3
# age 1013  is changed to 4
# age 1014  is changed to 3
# age 1015  is changed to 2
# age 1016  is changed to 4
# age 1017  is changed to 2
# age 1018  is changed to 3
# age 1019  is changed to 3
# age 1020  is changed to 4
# age 1021  is changed to 2
# age 1022  is changed to 4
# age 1023  is changed to 2
# age 1024  is changed to 4
# age 1025  is changed to 3
# age 1026  is changed to 2
# age 1027  is changed to 4
# age 1028  is changed to 2
# age 1029  is changed to 3
# age 1030  is changed to 2
# age 1031  is changed to 2
# age 1032  is changed to 3
# age 1033  is changed to 4
# age 1034  is changed to 3
# age 1035  is changed to 3
# age 1036  is changed to 2
# age 1037  is changed to 4
# age 1038  is changed to 3
# age 1039  is changed to 2
# age 1040  is changed to 3
# age 1041  is changed to 4
# age 1042  is changed to 2
# age 1043  is changed to 2
# age 1044  is changed to 5
# age 1045  is changed to 9
# age 1046  is changed to 3
# age 1047  is changed to 9
# age 1048  is changed to 2
# age 1049  is changed to 2
# age 1050  is changed to 2
# age 1051  is changed to 4
# age 1052  is changed to 3
# age 1053  is changed to 9
# age 1054  is changed to 4
# age 1055  is changed to 2
# age 1056  is changed to 2
# age 1057  is changed to 3
# age 1058  is changed to 5
# age 1059  is changed to 9
# age 1060  is changed to 3
# age 1061  is changed to 4
# age 1062  is changed to 2
# age 1063  is changed to 2
# age 1064  is changed to 2
# age 1065  is changed to 3
# age 1066  is changed to 3
# age 1067  is changed to 2
# age 1068  is changed to 4
# age 1069  is changed to 4
# age 1070  is changed to 4
# age 1071  is changed to 4
# age 1072  is changed to 2
# age 1073  is changed to 2
# age 1074  is changed to 3
# age 1075  is changed to 2
# age 1076  is changed to 3
# age 1077  is changed to 2
# age 1078  is changed to 2
# age 1079  is changed to 4
# age 1080  is changed to 2
# age 1081  is changed to 3
# age 1082  is changed to 4
# age 1083  is changed to 9
# age 1084  is changed to 2
# age 1085  is changed to 2
# age 1086  is changed to 2
# age 1087  is changed to 2
# age 1088  is changed to 4
# age 1089  is changed to 2
# age 1090  is changed to 2
# age 1091  is changed to 3
# age 1092  is changed to 3
# age 1093  is changed to 4
# age 1094  is changed to 2
# age 1095  is changed to 2
# age 1096  is changed to 9
# age 1097  is changed to 2
# age 1098  is changed to 2
# age 1099  is changed to 4
# age 1100  is changed to 2
# age 1101  is changed to 2
# age 1102  is changed to 2
# age 1103  is changed to 4
# age 1104  is changed to 2
# age 1105  is changed to 3
# age 1106  is changed to 6
# age 1107  is changed to 4
# age 1108  is changed to 3
# age 1109  is changed to 5
# age 1110  is changed to 2
# age 1111  is changed to 3
# age 1112  is changed to 4
# age 1113  is changed to 4
# age 1114  is changed to 2
# age 1115  is changed to 3
# age 1116  is changed to 3
# age 1117  is changed to 2
# age 1118  is changed to 3
# age 1119  is changed to 2
# age 1120  is changed to 2
# age 1121  is changed to 3
# age 1122  is changed to 3
# age 1123  is changed to 3
# age 1124  is changed to 4
# age 1125  is changed to 2
# age 1126  is changed to 3
# age 1127  is changed to 6
# age 1128  is changed to 3
# age 1129  is changed to 9
# age 1130  is changed to 2
# age 1131  is changed to 2
# age 1132  is changed to 9
# age 1133  is changed to 2
# age 1134  is changed to 3
# age 1135  is changed to 2
# age 1136  is changed to 2
# age 1137  is changed to 3
# age 1138  is changed to 5
# age 1139  is changed to 2
# age 1140  is changed to 3
# age 1141  is changed to 3
# age 1142  is changed to 4
# age 1143  is changed to 2
# age 1144  is changed to 4
# age 1145  is changed to 3
# age 1146  is changed to 3
# age 1147  is changed to 2
# age 1148  is changed to 3
# age 1149  is changed to 2
# age 1150  is changed to 2
# age 1151  is changed to 3
# age 1152  is changed to 9
# age 1153  is changed to 4
# age 1154  is changed to 9
# age 1155  is changed to 2
# age 1156  is changed to 2
# age 1157  is changed to 2
# age 1158  is changed to 2
# age 1159  is changed to 9
# age 1160  is changed to 4
# age 1161  is changed to 2
# age 1162  is changed to 4
# age 1163  is changed to 2
# age 1164  is changed to 2
# age 1165  is changed to 3
# age 1166  is changed to 2
# age 1167  is changed to 4
# age 1168  is changed to 3
# age 1169  is changed to 2
# age 1170  is changed to 2
# age 1171  is changed to 4
# age 1172  is changed to 3
# age 1173  is changed to 3
# age 1174  is changed to 4
# age 1175  is changed to 2
# age 1176  is changed to 4
# age 1177  is changed to 2
# age 1178  is changed to 4
# age 1179  is changed to 5
# age 1180  is changed to 2
# age 1181  is changed to 2
# age 1182  is changed to 5
# age 1183  is changed to 2
# age 1184  is changed to 5
# age 1185  is changed to 4
# age 1186  is changed to 4
# age 1187  is changed to 3
# age 1188  is changed to 3
# age 1189  is changed to 3
# age 1190  is changed to 4
# age 1191  is changed to 4
# age 1192  is changed to 3
# age 1193  is changed to 2
# age 1194  is changed to 9
# age 1195  is changed to 2
# age 1196  is changed to 3
# age 1197  is changed to 2
# age 1198  is changed to 3
# age 1199  is changed to 4
# age 1200  is changed to 2
# age 1201  is changed to 2
# age 1202  is changed to 2
# age 1203  is changed to 2
# age 1204  is changed to 2
# age 1205  is changed to 3
# age 1206  is changed to 2
# age 1207  is changed to 3
# age 1208  is changed to 2
# age 1209  is changed to 9
# age 1210  is changed to 4
# age 1211  is changed to 3
# age 1212  is changed to 3
# age 1213  is changed to 5
# age 1214  is changed to 4
# age 1215  is changed to 2
# age 1216  is changed to 2
# age 1217  is changed to 2
# age 1218  is changed to 5
# age 1219  is changed to 3
# age 1220  is changed to 3
# age 1221  is changed to 4
# age 1222  is changed to 2
# age 1223  is changed to 2
# age 1224  is changed to 3
# age 1225  is changed to 3
# age 1226  is changed to 3
# age 1227  is changed to 3
# age 1228  is changed to 2
# age 1229  is changed to 2
# age 1230  is changed to 9
# age 1231  is changed to 3
# age 1232  is changed to 9
# age 1233  is changed to 2
# age 1234  is changed to 2
# age 1235  is changed to 2
# age 1236  is changed to 3
# age 1237  is changed to 2
# age 1238  is changed to 3
# age 1239  is changed to 5
# age 1240  is changed to 2
# age 1241  is changed to 3
# age 1242  is changed to 4
# age 1243  is changed to 3
# age 1244  is changed to 3
# age 1245  is changed to 2
# age 1246  is changed to 2
# age 1247  is changed to 3
# age 1248  is changed to 4
# age 1249  is changed to 9
# age 1250  is changed to 2
# age 1251  is changed to 2
# age 1252  is changed to 2
# age 1253  is changed to 3
# age 1254  is changed to 3
# age 1255  is changed to 3
# age 1256  is changed to 2
# age 1257  is changed to 4
# age 1258  is changed to 2
# age 1259  is changed to 2
# age 1260  is changed to 4
# age 1261  is changed to 3
# age 1262  is changed to 9
# age 1263  is changed to 2
# age 1264  is changed to 3
# age 1265  is changed to 9
# age 1266  is changed to 9
# age 1267  is changed to 4
# age 1268  is changed to 9
# age 1269  is changed to 3
# age 1270  is changed to 2
# age 1271  is changed to 3
# age 1272  is changed to 2
# age 1273  is changed to 2
# age 1274  is changed to 4
# age 1275  is changed to 3
# age 1276  is changed to 3
# age 1277  is changed to 3
# age 1278  is changed to 3
# age 1279  is changed to 4
# age 1280  is changed to 8
# age 1281  is changed to 3
# age 1282  is changed to 3
# age 1283  is changed to 4
# age 1284  is changed to 3
# age 1285  is changed to 8
# age 1286  is changed to 4
# age 1287  is changed to 2
# age 1288  is changed to 5
# age 1289  is changed to 3
# age 1290  is changed to 3
# age 1291  is changed to 4
# age 1292  is changed to 2
# age 1293  is changed to 2
# age 1294  is changed to 2
# age 1295  is changed to 2
# age 1296  is changed to 2
# age 1297  is changed to 4
# age 1298  is changed to 4
# age 1299  is changed to 2
# age 1300  is changed to 2
# age 1301  is changed to 2
# age 1302  is changed to 2
# age 1303  is changed to 4
# age 1304  is changed to 4
# age 1305  is changed to 9
# age 1306  is changed to 2
# age 1307  is changed to 2
# age 1308  is changed to 3
# age 1309  is changed to 2
# age 1310  is changed to 4
# age 1311  is changed to 4
# age 1312  is changed to 2
# age 1313  is changed to 6
# age 1314  is changed to 4
# age 1315  is changed to 2
# age 1316  is changed to 4
# age 1317  is changed to 9
# age 1318  is changed to 3
# age 1319  is changed to 4
# age 1320  is changed to 2
# age 1321  is changed to 3
# age 1322  is changed to 4
# age 1323  is changed to 3
# age 1324  is changed to 2
# age 1325  is changed to 4
# age 1326  is changed to 2
# age 1327  is changed to 3
# age 1328  is changed to 9
# age 1329  is changed to 2
# age 1330  is changed to 4
# age 1331  is changed to 2
# age 1332  is changed to 2
# age 1333  is changed to 3
# age 1334  is changed to 9
# age 1335  is changed to 2
# age 1336  is changed to 3
# age 1337  is changed to 4
# age 1338  is changed to 2
# age 1339  is changed to 2
# age 1340  is changed to 2
# age 1341
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Streaming output truncated to the last 5000 lines.
# age 27950  is changed to 3
# age 27951  is changed to 3
# age 27952  is changed to 2
# age 27953  is changed to 3
# age 27954  is changed to 3
# age 27955  is changed to 4
# age 27956  is changed to 4
# age 27957  is changed to 3
# age 27958  is changed to 2
# age 27959  is changed to 2
# age 27960  is changed to 2
# age 27961  is changed to 4
# age 27962  is changed to 3
# age 27963  is changed to 5
# age 27964  is changed to 2
# age 27965  is changed to 3
# age 27966  is changed to 4
# age 27967  is changed to 2
# age 27968  is changed to 2
# age 27969  is changed to 2
# age 27970  is changed to 4
# age 27971  is changed to 3
# age 27972  is changed to 4
# age 27973  is changed to 3
# age 27974  is changed to 2
# age 27975  is changed to 2
# age 27976  is changed to 9
# age 27977  is changed to 2
# age 27978  is changed to 3
# age 27979  is changed to 2
# age 27980  is changed to 2
# age 27981  is changed to 2
# age 27982  is changed to 2
# age 27983  is changed to 3
# age 27984  is changed to 4
# age 27985  is changed to 2
# age 27986  is changed to 2
# age 27987  is changed to 4
# age 27988  is changed to 2
# age 27989  is changed to 4
# age 27990  is changed to 4
# age 27991  is changed to 2
# age 27992  is changed to 3
# age 27993  is changed to 2
# age 27994  is changed to 3
# age 27995  is changed to 4
# age 27996  is changed to 4
# age 27997  is changed to 3
# age 27998  is changed to 4
# age 27999  is changed to 3
# age 28000  is changed to 2
# age 28001  is changed to 4
# age 28002  is changed to 3
# age 28003  is changed to 4
# age 28004  is changed to 2
# age 28005  is changed to 4
# age 28006  is changed to 2
# age 28007  is changed to 2
# age 28008  is changed to 2
# age 28009  is changed to 9
# age 28010  is changed to 4
# age 28011  is changed to 2
# age 28012  is changed to 4
# age 28013  is changed to 9
# age 28014  is changed to 4
# age 28015  is changed to 4
# age 28016  is changed to 3
# age 28017  is changed to 4
# age 28018  is changed to 2
# age 28019  is changed to 2
# age 28020  is changed to 2
# age 28021  is changed to 2
# age 28022  is changed to 2
# age 28023  is changed to 4
# age 28024  is changed to 3
# age 28025  is changed to 3
# age 28026  is changed to 3
# age 28027  is changed to 4
# age 28028  is changed to 8
# age 28029  is changed to 2
# age 28030  is changed to 2
# age 28031  is changed to 2
# age 28032  is changed to 2
# age 28033  is changed to 3
# age 28034  is changed to 3
# age 28035  is changed to 5
# age 28036  is changed to 3
# age 28037  is changed to 4
# age 28038  is changed to 3
# age 28039  is changed to 3
# age 28040  is changed to 2
# age 28041  is changed to 2
# age 28042  is changed to 9
# age 28043  is changed to 5
# age 28044  is changed to 9
# age 28045  is changed to 2
# age 28046  is changed to 2
# age 28047  is changed to 2
# age 28048  is changed to 4
# age 28049  is changed to 2
# age 28050  is changed to 2
# age 28051  is changed to 4
# age 28052  is changed to 4
# age 28053  is changed to 6
# age 28054  is changed to 5
# age 28055  is changed to 2
# age 28056  is changed to 2
# age 28057  is changed to 3
# age 28058  is changed to 9
# age 28059  is changed to 4
# age 28060  is changed to 7
# age 28061  is changed to 2
# age 28062  is changed to 3
# age 28063  is changed to 4
# age 28064  is changed to 2
# age 28065  is changed to 2
# age 28066  is changed to 3
# age 28067  is changed to 3
# age 28068  is changed to 2
# age 28069  is changed to 9
# age 28070  is changed to 5
# age 28071  is changed to 2
# age 28072  is changed to 2
# age 28073  is changed to 4
# age 28074  is changed to 4
# age 28075  is changed to 3
# age 28076  is changed to 2
# age 28077  is changed to 3
# age 28078  is changed to 4
# age 28079  is changed to 9
# age 28080  is changed to 4
# age 28081  is changed to 3
# age 28082  is changed to 2
# age 28083  is changed to 3
# age 28084  is changed to 3
# age 28085  is changed to 2
# age 28086  is changed to 2
# age 28087  is changed to 3
# age 28088  is changed to 2
# age 28089  is changed to 9
# age 28090  is changed to 4
# age 28091  is changed to 3
# age 28092  is changed to 5
# age 28093  is changed to 4
# age 28094  is changed to 4
# age 28095  is changed to 3
# age 28096  is changed to 3
# age 28097  is changed to 4
# age 28098  is changed to 4
# age 28099  is changed to 5
# age 28100  is changed to 4
# age 28101  is changed to 2
# age 28102  is changed to 2
# age 28103  is changed to 2
# age 28104  is changed to 4
# age 28105  is changed to 3
# age 28106  is changed to 4
# age 28107  is changed to 2
# age 28108  is changed to 4
# age 28109  is changed to 4
# age 28110  is changed to 2
# age 28111  is changed to 2
# age 28112  is changed to 4
# age 28113  is changed to 2
# age 28114  is changed to 3
# age 28115  is changed to 2
# age 28116  is changed to 2
# age 28117  is changed to 2
# age 28118  is changed to 3
# age 28119  is changed to 6
# age 28120  is changed to 3
# age 28121  is changed to 3
# age 28122  is changed to 2
# age 28123  is changed to 2
# age 28124  is changed to 2
# age 28125  is changed to 2
# age 28126  is changed to 2
# age 28127  is changed to 2
# age 28128  is changed to 2
# age 28129  is changed to 4
# age 28130  is changed to 2
# age 28131  is changed to 4
# age 28132  is changed to 4
# age 28133  is changed to 2
# age 28134  is changed to 2
# age 28135  is changed to 4
# age 28136  is changed to 2
# age 28137  is changed to 4
# age 28138  is changed to 7
# age 28139  is changed to 2
# age 28140  is changed to 2
# age 28141  is changed to 3
# age 28142  is changed to 2
# age 28143  is changed to 9
# age 28144  is changed to 2
# age 28145  is changed to 3
# age 28146  is changed to 3
# age 28147  is changed to 2
# age 28148  is changed to 4
# age 28149  is changed to 4
# age 28150  is changed to 4
# age 28151  is changed to 2
# age 28152  is changed to 2
# age 28153  is changed to 3
# age 28154  is changed to 3
# age 28155  is changed to 9
# age 28156  is changed to 3
# age 28157  is changed to 4
# age 28158  is changed to 2
# age 28159  is changed to 3
# age 28160  is changed to 9
# age 28161  is changed to 2
# age 28162  is changed to 3
# age 28163  is changed to 4
# age 28164  is changed to 2
# age 28165  is changed to 3
# age 28166  is changed to 2
# age 28167  is changed to 3
# age 28168  is changed to 4
# age 28169  is changed to 4
# age 28170  is changed to 2
# age 28171  is changed to 2
# age 28172  is changed to 4
# age 28173  is changed to 3
# age 28174  is changed to 3
# age 28175  is changed to 2
# age 28176  is changed to 3
# age 28177  is changed to 3
# age 28178  is changed to 4
# age 28179  is changed to 3
# age 28180  is changed to 5
# age 28181  is changed to 4
# age 28182  is changed to 2
# age 28183  is changed to 3
# age 28184  is changed to 4
# age 28185  is changed to 2
# age 28186  is changed to 2
# age 28187  is changed to 5
# age 28188  is changed to 2
# age 28189  is changed to 3
# age 28190  is changed to 9
# age 28191  is changed to 2
# age 28192  is changed to 3
# age 28193  is changed to 4
# age 28194  is changed to 4
# age 28195  is changed to 2
# age 28196  is changed to 4
# age 28197  is changed to 3
# age 28198  is changed to 5
# age 28199  is changed to 2
# age 28200  is changed to 4
# age 28201  is changed to 3
# age 28202  is changed to 4
# age 28203  is changed to 4
# age 28204  is changed to 3
# age 28205  is changed to 3
# age 28206  is changed to 3
# age 28207  is changed to 4
# age 28208  is changed to 5
# age 28209  is changed to 4
# age 28210  is changed to 2
# age 28211  is changed to 3
# age 28212  is changed to 4
# age 28213  is changed to 3
# age 28214  is changed to 2
# age 28215  is changed to 4
# age 28216  is changed to 2
# age 28217  is changed to 2
# age 28218  is changed to 5
# age 28219  is changed to 2
# age 28220  is changed to 4
# age 28221  is changed to 4
# age 28222  is changed to 3
# age 28223  is changed to 2
# age 28224  is changed to 2
# age 28225  is changed to 2
# age 28226  is changed to 9
# age 28227  is changed to 2
# age 28228  is changed to 5
# age 28229  is changed to 2
# age 28230  is changed to 2
# age 28231  is changed to 3
# age 28232  is changed to 4
# age 28233  is changed to 2
# age 28234  is changed to 2
# age 28235  is changed to 2
# age 28236  is changed to 3
# age 28237  is changed to 2
# age 28238  is changed to 3
# age 28239  is changed to 2
# age 28240  is changed to 4
# age 28241  is changed to 3
# age 28242  is changed to 3
# age 28243  is changed to 2
# age 28244  is changed to 2
# age 28245  is changed to 2
# age 28246  is changed to 6
# age 28247  is changed to 2
# age 28248  is changed to 2
# age 28249  is changed to 2
# age 28250  is changed to 2
# age 28251  is changed to 5
# age 28252  is changed to 4
# age 28253  is changed to 4
# age 28254  is changed to 4
# age 28255  is changed to 6
# age 28256  is changed to 5
# age 28257  is changed to 4
# age 28258  is changed to 4
# age 28259  is changed to 5
# age 28260  is changed to 3
# age 28261  is changed to 2
# age 28262  is changed to 4
# age 28263  is changed to 2
# age 28264  is changed to 2
# age 28265  is changed to 2
# age 28266  is changed to 2
# age 28267  is changed to 3
# age 28268  is changed to 3
# age 28269  is changed to 2
# age 28270  is changed to 3
# age 28271  is changed to 3
# age 28272  is changed to 2
# age 28273  is changed to 4
# age 28274  is changed to 2
# age 28275  is changed to 3
# age 28276  is changed to 3
# age 28277  is changed to 2
# age 28278  is changed to 4
# age 28279  is changed to 3
# age 28280  is changed to 3
# age 28281  is changed to 3
# age 28282  is changed to 3
# age 28283  is changed to 2
# age 28284  is changed to 2
# age 28285  is changed to 2
# age 28286  is changed to 4
# age 28287  is changed to 6
# age 28288  is changed to 2
# age 28289  is changed to 4
# age 28290  is changed to 2
# age 28291  is changed to 2
# age 28292  is changed to 3
# age 28293  is changed to 6
# age 28294  is changed to 3
# age 28295  is changed to 4
# age 28296  is changed to 3
# age 28297  is changed to 2
# age 28298  is changed to 2
# age 28299  is changed to 2
# age 28300  is changed to 9
# age 28301  is changed to 3
# age 28302  is changed to 5
# age 28303  is changed to 4
# age 28304  is changed to 2
# age 28305  is changed to 5
# age 28306  is changed to 2
# age 28307  is changed to 3
# age 28308  is changed to 2
# age 28309  is changed to 3
# age 28310  is changed to 2
# age 28311  is changed to 2
# age 28312  is changed to 2
# age 28313  is changed to 2
# age 28314  is changed to 3
# age 28315  is changed to 5
# age 28316  is changed to 4
# age 28317  is changed to 4
# age 28318  is changed to 3
# age 28319  is changed to 2
# age 28320  is changed to 2
# age 28321  is changed to 3
# age 28322  is changed to 4
# age 28323  is changed to 2
# age 28324  is changed to 2
# age 28325  is changed to 5
# age 28326  is changed to 3
# age 28327  is changed to 5
# age 28328  is changed to 2
# age 28329  is changed to 2
# age 28330  is changed to 5
# age 28331  is changed to 6
# age 28332  is changed to 2
# age 28333  is changed to 4
# age 28334  is changed to 5
# age 28335  is changed to 2
# age 28336  is changed to 3
# age 28337  is changed to 5
# age 28338  is changed to 3
# age 28339  is changed to 5
# age 28340  is changed to 4
# age 28341  is changed to 2
# age 28342  is changed to 2
# age 28343  is changed to 5
# age 28344  is changed to 2
# age 28345  is changed to 2
# age 28346  is changed to 2
# age 28347  is changed to 4
# age 28348  is changed to 4
# age 28349  is changed to 9
# age 28350  is changed to 4
# age 28351  is changed to 3
# age 28352  is changed to 3
# age 28353  is changed to 4
# age 28354  is changed to 2
# age 28355  is changed to 2
# ...
# age 32358  is changed to 2
# age 32359  is changed to 3
# age 32360  is changed to 2
# age 32361  is changed to 3
# age 32362  is changed to 3
# age 32363  is changed to 4
# age 32364  is changed to 4
# age 32365  is changed to 4
# age 32366  is changed to 2
# age 32367  is changed to 3
# age 32368  is changed to 4
# age 32369  is changed to 3
# age 32370  is changed to 3
# age 32371  is changed to 2
# age 32372  is changed to 5
# age 32373  is changed to 2
# age 32374  is changed to 3
# age 32375  is changed to 2
# age 32376  is changed to 2
# age 32377  is changed to 2
# age 32378  is changed to 2
# age 32379  is changed to 5
# age 32380  is changed to 3
# age 32381  is changed to 2
# age 32382  is changed to 2
# age 32383  is changed to 4
# age 32384  is changed to 2
# age 32385  is changed to 2
# age 32386  is changed to 3
# age 32387  is changed to 2
# age 32388  is changed to 2
# age 32389  is changed to 2
# age 32390  is changed to 2
# age 32391  is changed to 4
# age 32392  is changed to 3
# age 32393  is changed to 4
# age 32394  is changed to 9
# age 32395  is changed to 4
# age 32396  is changed to 2
# age 32397  is changed to 2
# age 32398  is changed to 2
# age 32399  is changed to 3
# age 32400  is changed to 3
# age 32401  is changed to 2
# age 32402  is changed to 3
# age 32403  is changed to 2
# age 32404  is changed to 5
# age 32405  is changed to 2
# age 32406  is changed to 4
# age 32407  is changed to 3
# age 32408  is changed to 4
# age 32409  is changed to 4
# age 32410  is changed to 3
# age 32411  is changed to 4
# age 32412  is changed to 4
# age 32413  is changed to 3
# age 32414  is changed to 5
# age 32415  is changed to 4
# age 32416  is changed to 4
# age 32417  is changed to 4
# age 32418  is changed to 2
# age 32419  is changed to 2
# age 32420  is changed to 3
# age 32421  is changed to 4
# age 32422  is changed to 3
# age 32423  is changed to 2
# age 32424  is changed to 2
# age 32425  is changed to 2
# age 32426  is changed to 4
# age 32427  is changed to 3
# age 32428  is changed to 4
# age 32429  is changed to 2
# age 32430  is changed to 5
# age 32431  is changed to 2
# age 32432  is changed to 2
# age 32433  is changed to 2
# age 32434  is changed to 3
# age 32435  is changed to 2
# age 32436  is changed to 2
# age 32437  is changed to 4
# age 32438  is changed to 4
# age 32439  is changed to 3
# age 32440  is changed to 2
# age 32441  is changed to 2
# age 32442  is changed to 4
# age 32443  is changed to 2
# age 32444  is changed to 3
# age 32445  is changed to 4
# age 32446  is changed to 2
# age 32447  is changed to 2
# age 32448  is changed to 2
# age 32449  is changed to 2
# age 32450  is changed to 2
# age 32451  is changed to 3
# age 32452  is changed to 4
# age 32453  is changed to 2
# age 32454  is changed to 5
# age 32455  is changed to 2
# age 32456  is changed to 2
# age 32457  is changed to 3
# age 32458  is changed to 3
# age 32459  is changed to 4
# age 32460  is changed to 2
# age 32461  is changed to 9
# age 32462  is changed to 4
# age 32463  is changed to 3
# age 32464  is changed to 6
# age 32465  is changed to 3
# age 32466  is changed to 3
# age 32467  is changed to 2
# age 32468  is changed to 5
# age 32469  is changed to 4
# age 32470  is changed to 3
# age 32471  is changed to 3
# age 32472  is changed to 6
# age 32473  is changed to 3
# age 32474  is changed to 2
# age 32475  is changed to 3
# age 32476  is changed to 9
# age 32477  is changed to 2
# age 32478  is changed to 4
# age 32479  is changed to 3
# age 32480  is changed to 2
# age 32481  is changed to 2
# age 32482  is changed to 2
# age 32483  is changed to 3
# age 32484  is changed to 4
# age 32485  is changed to 2
# age 32486  is changed to 5
# age 32487  is changed to 2
# age 32488  is changed to 2
# age 32489  is changed to 2
# age 32490  is changed to 2
# age 32491  is changed to 4
# age 32492  is changed to 2
# age 32493  is changed to 2
# age 32494  is changed to 3
# age 32495  is changed to 2
# age 32496  is changed to 4
# age 32497  is changed to 5
# age 32498  is changed to 3
# age 32499  is changed to 3
# age 32500  is changed to 2
# age 32501  is changed to 2
# age 32502  is changed to 2
# age 32503  is changed to 3
# age 32504  is changed to 2
# age 32505  is changed to 3
# age 32506  is changed to 5
# age 32507  is changed to 5
# age 32508  is changed to 2
# age 32509  is changed to 4
# age 32510  is changed to 3
# age 32511  is changed to 2
# age 32512  is changed to 2
# age 32513  is changed to 2
# age 32514  is changed to 2
# age 32515  is changed to 4
# age 32516  is changed to 2
# age 32517  is changed to 2
# age 32518  is changed to 2
# age 32519  is changed to 3
# age 32520  is changed to 3
# age 32521  is changed to 2
# age 32522  is changed to 2
# age 32523  is changed to 3
# age 32524  is changed to 3
# age 32525  is changed to 5
# age 32526  is changed to 2
# age 32527  is changed to 4
# age 32528  is changed to 3
# age 32529  is changed to 2
# age 32530  is changed to 3
# age 32531  is changed to 4
# age 32532  is changed to 2
# age 32533  is changed to 2
# age 32534  is changed to 2
# age 32535  is changed to 2
# age 32536  is changed to 2
# age 32537  is changed to 4
# age 32538  is changed to 4
# age 32539  is changed to 2
# age 32540  is changed to 3
# age 32541  is changed to 2
# age 32542  is changed to 2
# age 32543  is changed to 2
# age 32544  is changed to 2
# age 32545  is changed to 2
# age 32546  is changed to 6
# age 32547  is changed to 4
# age 32548  is changed to 2
# age 32549  is changed to 2
# age 32550  is changed to 3
# age 32551  is changed to 3
# age 32552  is changed to 2
# age 32553  is changed to 9
# age 32554  is changed to 7
# age 32555  is changed to 3
# age 32556  is changed to 3
# age 32557  is changed to 4
# age 32558  is changed to 4
# age 32559  is changed to 2
# age 32560  is changed to 9
# age 32561  is changed to 2
# age 32562  is changed to 5
# age 32563  is changed to 3
# age 32564  is changed to 4
# age 32565  is changed to 3
# age 32566  is changed to 5
# age 32567  is changed to 6
# age 32568  is changed to 4
# age 32569  is changed to 9
# age 32570  is changed to 2
# age 32571  is changed to 3
# age 32572  is changed to 4
# age 32573  is changed to 2
# age 32574  is changed to 2
# age 32575  is changed to 2
# age 32576  is changed to 3
# age 32577  is changed to 2
# age 32578  is changed to 4
# age 32579  is changed to 9
# age 32580  is changed to 9
# age 32581  is changed to 4
# age 32582  is changed to 2
# age 32583  is changed to 2
# age 32584  is changed to 4
# age 32585  is changed to 4
# age 32586  is changed to 2
# age 32587  is changed to 3
# age 32588  is changed to 5
# age 32589  is changed to 5
# age 32590  is changed to 3
# age 32591  is changed to 4
# age 32592  is changed to 3
# age 32593  is changed to 2
# age 32594  is changed to 9
# age 32595  is changed to 5
# age 32596  is changed to 9
# age 32597  is changed to 3
# age 32598  is changed to 3
# age 32599  is changed to 2
# age 32600  is changed to 2
# age 32601  is changed to 3
# age 32602  is changed to 2
# age 32603  is changed to 5
# age 32604  is changed to 2
# age 32605  is changed to 4
# age 32606  is changed to 2
# age 32607  is changed to 3
# age 32608  is changed to 2
# age 32609  is changed to 3
# age 32610  is changed to 2
# age 32611  is changed to 5
# age 32612  is changed to 9
# age 32613  is changed to 2
# age 32614  is changed to 3
# age 32615  is changed to 3
# age 32616  is changed to 3
# age 32617  is changed to 4
# age 32618  is changed to 2
# age 32619  is changed to 2
# age 32620  is changed to 5
# age 32621  is changed to 2
# age 32622  is changed to 5
# age 32623  is changed to 4
# age 32624  is changed to 3
# age 32625  is changed to 9
# age 32626  is changed to 9
# age 32627  is changed to 3
# age 32628  is changed to 4
# age 32629  is changed to 2
# age 32630  is changed to 3
# age 32631  is changed to 4
# age 32632  is changed to 9
# age 32633  is changed to 3
# age 32634  is changed to 2
# age 32635  is changed to 4
# age 32636  is changed to 4
# age 32637  is changed to 4
# age 32638  is changed to 2
# age 32639  is changed to 2
# age 32640  is changed to 9
# age 32641  is changed to 2
# age 32642  is changed to 2
# age 32643  is changed to 2
# age 32644  is changed to 9
# age 32645  is changed to 2
# age 32646  is changed to 3
# age 32647  is changed to 3
# age 32648  is changed to 2
# age 32649  is changed to 4
# age 32650  is changed to 4
# age 32651  is changed to 3
# age 32652  is changed to 4
# age 32653  is changed to 5
# age 32654  is changed to 3
# age 32655  is changed to 4
# age 32656  is changed to 2
# age 32657  is changed to 4
# age 32658  is changed to 2
# age 32659  is changed to 9
# age 32660  is changed to 2
# age 32661  is changed to 3
# age 32662  is changed to 4
# age 32663  is changed to 2
# age 32664  is changed to 3
# age 32665  is changed to 2
# age 32666  is changed to 3
# age 32667  is changed to 4
# age 32668  is changed to 4
# age 32669  is changed to 2
# age 32670  is changed to 3
# age 32671  is changed to 2
# age 32672  is changed to 2
# age 32673  is changed to 3
# age 32674  is changed to 4
# age 32675  is changed to 2
# age 32676  is changed to 3
# age 32677  is changed to 2
# age 32678  is changed to 3
# age 32679  is changed to 3
# age 32680  is changed to 4
# age 32681  is changed to 3
# age 32682  is changed to 4
# age 32683  is changed to 3
# age 32684  is changed to 4
# age 32685  is changed to 4
# age 32686  is changed to 3
# age 32687  is changed to 2
# age 32688  is changed to 9
# age 32689  is changed to 2
# age 32690  is changed to 2
# age 32691  is changed to 4
# age 32692  is changed to 4
# age 32693  is changed to 2
# age 32694  is changed to 3
# age 32695  is changed to 2
# age 32696  is changed to 4
# age 32697  is changed to 3
# age 32698  is changed to 2
# age 32699  is changed to 9
# age 32700  is changed to 3
# age 32701  is changed to 4
# age 32702  is changed to 2
# age 32703  is changed to 3
# age 32704  is changed to 3
# age 32705  is changed to 3
# age 32706  is changed to 2
# age 32707  is changed to 4
# age 32708  is changed to 4
# age 32709  is changed to 4
# age 32710  is changed to 2
# age 32711  is changed to 2
# age 32712  is changed to 3
# age 32713  is changed to 3
# age 32714  is changed to 3
# age 32715  is changed to 3
# age 32716  is changed to 4
# age 32717  is changed to 2
# age 32718  is changed to 2
# age 32719  is changed to 2
# age 32720  is changed to 4
# age 32721  is changed to 2
# age 32722  is changed to 5
# age 32723  is changed to 2
# age 32724  is changed to 3
# age 32725  is changed to 2
# age 32726  is changed to 2
# age 32727  is changed to 2
# age 32728  is changed to 3
# age 32729  is changed to 4
# age 32730  is changed to 3
# age 32731  is changed to 2
# age 32732  is changed to 2
# age 32733  is changed to 4
# age 32734  is changed to 4
# age 32735  is changed to 2
# age 32736  is changed to 4
# age 32737  is changed to 2
# age 32738  is changed to 4
# age 32739  is changed to 2
# age 32740  is changed to 2
# age 32741  is changed to 4
# age 32742  is changed to 4
# age 32743  is changed to 3
# age 32744  is changed to 5
# age 32745  is changed to 3
# age 32746  is changed to 3
# age 32747  is changed to 4
# age 32748  is changed to 3
# age 32749  is changed to 2
# age 32750  is changed to 2
# age 32751  is changed to 9
# age 32752  is changed to 3
# age 32753  is changed to 5
# age 32754  is changed to 3
# age 32755  is changed to 2
# age 32756  is changed to 2
# age 32757  is changed to 2
# age 32758  is changed to 2
# age 32759  is changed to 2
# age 32760  is changed to 4
# age 32761  is changed to 2
# age 32762  is changed to 3
# age 32763  is changed to 3
# age 32764  is changed to 2
# age 32765  is changed to 3
# age 32766  is changed to 2
# age 32767  is changed to 2
# age 32768  is changed to 2
# age 32769  is changed to 5
# age 32770  is changed to 5
# age 32771  is changed to 4
# age 32772  is changed to 2
# age 32773  is changed to 2
# age 32774  is changed to 2
# age 32775  is changed to 2
# age 32776  is changed to 3
# age 32777  is changed to 3
# age 32778  is changed to 3
# age 32779  is changed to 5
# age 32780  is changed to 3
# age 32781  is changed to 3
# age 32782  is changed to 2
# age 32783  is changed to 3
# age 32784  is changed to 4
# age 32785  is changed to 4
# age 32786  is changed to 5
# age 32787  is changed to 3
# age 32788  is changed to 4
# age 32789  is changed to 4
# age 32790  is changed to 2
# age 32791  is changed to 4
# age 32792  is changed to 3
# age 32793  is changed to 2
# age 32794  is changed to 9
# age 32795  is changed to 3
# age 32796  is changed to 4
# age 32797  is changed to 3
# age 32798  is changed to 2
# age 32799  is changed to 5
# age 32800  is changed to 2
# age 32801  is changed to 2
# age 32802  is changed to 4
# age 32803  is changed to 3
# age 32804  is changed to 4
# age 32805  is changed to 9
# age 32806  is changed to 3
# age 32807  is changed to 2
# age 32808  is changed to 9
# age 32809  is changed to 2
# age 32810  is changed to 4
# age 32811  is changed to 2
# age 32812  is changed to 3
# age 32813  is changed to 3
# age 32814  is changed to 4
# age 32815  is changed to 4
# age 32816  is changed to 3
# age 32817  is changed to 3
# age 32818  is changed to 3
# age 32819  is changed to 3
# age 32820  is changed to 2
# age 32821  is changed to 4
# age 32822  is changed to 5
# age 32823  is changed to 2
# age 32824  is changed to 9
# age 32825  is changed to 3
# age 32826  is changed to 7
# age 32827  is changed to 2
# age 32828  is changed to 2
# age 32829  is changed to 3
# age 32830  is changed to 4
# age 32831  is changed to 4
# age 32832  is changed to 3
# age 32833  is changed to 3
# age 32834  is changed to 3
# age 32835  is changed to 5
# age 32836  is changed to 3
# age 32837  is changed to 4
# age 32838  is changed to 3
# age 32839  is changed to 2
# age 32840  is changed to 2
# age 32841  is changed to 3
# age 32842  is changed to 2
# age 32843  is changed to 4
# age 32844  is changed to 5
# age 32845  is changed to 3
# age 32846  is changed to 3
# age 32847  is changed to 3
# age 32848  is changed to 4
# age 32849  is changed to 5
# age 32850  is changed to 5
# age 32851  is changed to 3
# age 32852  is changed to 3
# age 32853  is changed to 2
# age 32854  is changed to 9
# age 32855  is changed to 3
# age 32856  is changed to 4
# age 32857  is changed to 2
# age 32858  is changed to 3
# age 32859  is changed to 2
# age 32860  is changed to 2
# age 32861  is changed to 2
# age 32862  is changed to 2
# age 32863  is changed to 2
# age 32864  is changed to 3
# age 32865  is changed to 2
# age 32866  is changed to 4
# age 32867  is changed to 9
# age 32868  is changed to 3
# age 32869  is changed to 2
# age 32870  is changed to 2
# age 32871  is changed to 2
# age 32872  is changed to 3
# age 32873  is changed to 3
# age 32874  is changed to 3
# age 32875  is changed to 2
# age 32876  is changed to 4
# age 32877  is changed to 4
# age 32878  is changed to 4
# age 32879  is changed to 3
# age 32880  is changed to 4
# age 32881  is changed to 4
# age 32882  is changed to 9
# age 32883  is changed to 3
# age 32884  is changed to 2
# age 32885  is changed to 4
# age 32886  is changed to 4
# age 32887  is changed to 3
# age 32888  is changed to 3
# age 32889  is changed to 3
# age 32890  is changed to 2
# age 32891  is changed to 2
# age 32892  is changed to 9
# age 32893  is changed to 2
# age 32894  is changed to 4
# age 32895  is changed to 3
# age 32896  is changed to 2
# age 32897  is changed to 4
# age 32898  is changed to 4
# age 32899  is changed to 3
# age 32900  is changed to 4
# age 32901  is changed to 2
# age 32902  is changed to 4
# age 32903  is changed to 4
# age 32904  is changed to 9
# age 32905  is changed to 2
# age 32906  is changed to 2
# age 32907  is changed to 2
# age 32908  is changed to 5
# age 32909  is changed to 3
# age 32910  is changed to 2
# age 32911  is changed to 2
# age 32912  is changed to 9
# age 32913  is changed to 5
# age 32914  is changed to 4
# age 32915  is changed to 2
# age 32916  is changed to 3
# age 32917  is changed to 6
# age 32918  is changed to 2
# age 32919  is changed to 4
# age 32920  is changed to 4
# age 32921  is changed to 3
# age 32922  is changed to 3
# age 32923  is changed to 3
# age 32924  is changed to 4
# age 32925  is changed to 2
# age 32926  is changed to 9
# age 32927  is changed to 4
# age 32928  is changed to 2
# age 32929  is changed to 4
# age 32930  is changed to 3
# age 32931  is changed to 4
# age 32932  is changed to 4
# age 32933  is changed to 2
# age 32934  is changed to 2
# age 32935  is changed to 2
# age 32936  is changed to 2
# age 32937  is changed to 2
# age 32938  is changed to 3
# age 32939  is changed to 3
# age 32940  is changed to 2
# age 32941  is changed to 2
# age 32942  is changed to 3
# age 32943  is changed to 4
# age 32944  is changed to 2
# age 32945  is changed to 2
# age 32946  is changed to 4
# age 32947  is changed to 4
# age 32948  is changed to 2
# age 32949  is changed to 9

# %%
for i in range(0, len(df.y)):
  if df.y[i] == 'no':
    df.y[i] = 0
  else:
    df.y[i] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
for i in range(0, len(df.job)):
  if df.job[i] == 'admin.':
    df.job[i] = 0
  elif df.job[i] == 'blue-collar':
    df.job[i] = 1
  elif df.job[i] == 'entrepreneur':
    df.job[i] = 2
  elif df.job[i] == 'housemaid':
    df.job[i] = 3
  elif df.job[i] == 'management':
    df.job[i] = 4
  elif df.job[i] == 'retired':
    df.job[i] = 5
  elif df.job[i] == 'self-employed':
    df.job[i] = 6
  elif df.job[i] == 'services':
    df.job[i] = 7
  elif df.job[i] == 'student':
    df.job[i] = 8
  elif df.job[i] == 'technician':
    df.job[i] = 9
  elif df.job[i] == 'unemployed':
    df.job[i] = 10
  elif df.job[i] == 'unknown':
    df.job[i] = 11
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
df.head()
# Out:
#    age job   marital          education  default housing loan    contact  \
# 0    4   1   married           basic.9y  unknown      no   no   cellular
# 1    3   2   married  university.degree       no      no   no  telephone
# 2    7   5   married           basic.4y       no      no   no   cellular
# 3    3   0   married  university.degree       no     yes   no  telephone
# 4    5   5  divorced  university.degree       no      no   no   cellular
#
#   month day_of_week  duration  previous     poutcome  y
# 0   nov         wed       227         0  nonexistent  0
# 1   nov         wed       202         1      failure  0
# 2   jul         mon      1148         0  nonexistent  1
# 3   may         mon       120         0  nonexistent  0
# 4   jun         tue       368         0  nonexistent  0

# %%
for i in range(0, len(df.marital)):
  if df.marital[i] == 'divorced':
    df.marital[i] = 0
  elif df.marital[i] == 'married':
    df.marital[i] = 1
  elif df.marital[i] == 'single':
    df.marital[i] = 2
  elif df.marital[i] == 'unknown':
    df.marital[i] = 3
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
for i in range(0, len(df.education)):
  if df.education[i] == 'basic.4y':
    df.education[i] = 0
  elif df.education[i] == 'basic.6y':
    df.education[i] = 1
  elif df.education[i] == 'basic.9y':
    df.education[i] = 2
  elif df.education[i] == 'high.school':
    df.education[i] = 3
  elif df.education[i] == 'illiterate':
    df.education[i] = 4
  elif df.education[i] == 'professional.course':
    df.education[i] = 5
  elif df.education[i] == 'university.degree':
    df.education[i] = 6
  elif df.education[i] == 'unknown':
    df.education[i] = 7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
for i in range(0, len(df.default)):
  if df.default[i] == 'no':
    df.default[i] = 0
  elif df.default[i] == 'yes':
    df.default[i] = 1
  elif df.default[i] == 'unknown':
    df.default[i] = 2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
for i in range(0, len(df.housing)):
  if df.housing[i] == 'no':
    df.housing[i] = 0
  elif df.housing[i] == 'yes':
    df.housing[i] = 1
  elif df.housing[i] == 'unknown':
    df.housing[i] = 2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
for i in range(0, len(df.loan)):
  if df.loan[i] == 'no':
    df.loan[i] = 0
  elif df.loan[i] == 'yes':
    df.loan[i] = 1
  elif df.loan[i] == 'unknown':
    df.loan[i] = 2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
for i in range(0, len(df.contact)):
  if df.contact[i] == 'cellular':
    df.contact[i] = 0
  elif df.contact[i] == 'telephone':
    df.contact[i] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df.head()
# Out:
#    age job marital education default housing loan contact month day_of_week  \
# 0    4   1       1         2       2       0    0       0   nov         wed
# 1    3   2       1         6       0       0    0       1   nov         wed
# 2    7   5       1         0       0       0    0       0   jul         mon
# 3    3   0       1         6       0       1    0       1   may         mon
# 4    5   5       0         6       0       0    0       0   jun         tue
#
#    duration  previous     poutcome  y
# 0       227         0  nonexistent  0
# 1       202         1      failure  0
# 2      1148         0  nonexistent  1
# 3       120         0  nonexistent  0
# 4       368         0  nonexistent  0

# %%
for i in range(0, len(df.month)):
  if df.month[i] == 'jan':
    df.month[i] = 0
  elif df.month[i] == 'feb':
    df.month[i] = 1
  elif df.month[i] == 'mar':
    df.month[i] = 2
  elif df.month[i] == 'apr':
    df.month[i] = 3
  elif df.month[i] == 'may':
    df.month[i] = 4
  elif df.month[i] == 'jun':
    df.month[i] = 5
  elif df.month[i] == 'jul':
    df.month[i] = 6
  elif df.month[i] == 'aug':
    df.month[i] = 7
  elif df.month[i] == 'sep':
    df.month[i] = 8
  elif df.month[i] == 'oct':
    df.month[i] = 9
  elif df.month[i] == 'nov':
    df.month[i] = 10
  elif df.month[i] == 'dec':
    df.month[i] = 11
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i in range(0, len(df.day_of_week)):
  if df.day_of_week[i] == 'mon':
    df.day_of_week[i] = 0
  elif df.day_of_week[i] == 'tue':
    df.day_of_week[i] = 1
  elif df.day_of_week[i] == 'wed':
    df.day_of_week[i] = 2
  elif df.day_of_week[i] == 'thu':
    df.day_of_week[i] = 3
  elif df.day_of_week[i] == 'fri':
    df.day_of_week[i] = 4
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
for i in range(0, len(df.duration)):
  if df.duration[i] == 0:
    df.duration[i] = 0
  else:
    df.duration[i] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for i in range(0, len(df.poutcome)):
  if df.poutcome[i] == 'failure':
    df.poutcome[i] = 0
  elif df.poutcome[i] == 'nonexistent':
    df.poutcome[i] = 1
  else:
    df.poutcome[i] = 2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df.head()
# Out:
#    age job marital education default housing loan contact month day_of_week  \
# 0    4   1       1         2       2       0    0       0    10           2
# 1    3   2       1         6       0       0    0       1    10           2
# 2    7   5       1         0       0       0    0       0     6           0
# 3    3   0       1         6       0       1    0       1     4           0
# 4    5   5       0         6       0       0    0       0     5           1
#
#    duration  previous poutcome  y
# 0         1         0        1  0
# 1         1         1        0  0
# 2         1         0        1  1
# 3         1         0        1  0
# 4         1         0        1  0

# %%
# chọn bằng hệ số tương quan
cor = df.corr()

# %%
cotdt = ['age', 'job', 'marital', 'education', 'default',	'housing', 'loan',	'contact',	'month',	'day_of_week', 'poutcome']

# %%
x = df[cotdt]
y = df['y'].astype('int')

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=26)

clf = DecisionTreeClassifier(criterion='entropy', max_depth=5)
clf = clf.fit(X_train, y_train)

predictions = clf.predict(X_test)

# %%
import numpy as np  
from sklearn.model_selection import train_test_split  
from sklearn.svm import SVC

# %%
svc = SVC()  
svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
def compute_accuracy(Y_true, Y_pred):  
    correctly_predicted = 0  
    # lặp lại nhãn và kiểm tra độ trính xác  
    for true_label, predicted in zip(Y_true, Y_pred):  
        if true_label == predicted:  
            correctly_predicted += 1  
    # Tính toán điểm chính xác của việc so sánh   
    accuracy_score = correctly_predicted / len(Y_true)  
    return accuracy_score

# %%
Y_pred = svc.predict(X_test)  
score = compute_accuracy(y_test, Y_pred)  
print(score)
# Out:
# 0.8867374810318664
